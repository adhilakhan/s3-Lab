# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
import matplotlib.pyplot as plt

# %%
np.random.seed(42)
x=2*np.random.rand(100,1)
y=4+3*x+np.random.rand(100,1) #adding noises,c=4,m=3

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=42)

# %%
classifier=LinearRegression()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 classifier=LinearRegression()
#
# NameError: name 'LinearRegression' is not defined

# %%
classifier.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=classifier.predict(X_test)

# %%
r2_score(y_test,y_predict)
# Out:
# 0.9742947589810751

# %%
msc=mean_squared_error(y_test,y_predict)
print(msc) #difference between predicted and actual
# Out:
# 0.09544303469758966

# %%
plt.scatter(x,y,color="indigo",marker="d",label="Actual Data")
plt.show()

# %%
plt.plot(X_test,y_test)
plt.show()

# %%
n=float(input("Enter the value to predict"))
n_reshape=np.array([[n]])
n_predict=classifier.predict(n_reshape)
print(n_predict)
