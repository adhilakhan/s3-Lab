# %%
import numpy as np
import matplotlib.pyplot as plt
overs=[5,10,15,20]
runs=[45,79,145,234]
plt.title("T-20 Run Rate")
plt.xlabel("Overs")
plt.ylabel("Runs")
plt.plot(overs,runs,color='black',linewidth=3)
plt.show()
